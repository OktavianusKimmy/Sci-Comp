# %% [markdown]
# NO 2

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [2.1, 2.3, 2.6, 3.0, 3.5, 4.1]
y = [5.2, 5.5, 6.0, 6.8, 7.1, 8.0]

x = np.array(x)
y = np.array(y)

A = np.vstack([x, np.ones(len(x))]).T
y = y[:, np.newaxis]

alpha = np.linalg.inv(np.dot(A.T, A)).T
alpha = np.dot(alpha, A.T)
alpha = np.dot(alpha, y)

print(f"Alpha (m dan c): {alpha[0]}")
print(alpha[1])

plt.plot(x, y, "ro")
plt.plot(x, alpha[0]*x+alpha[1], 'b')
plt.show()
# Out:
# Alpha (m dan c): [1.38018433]
# [2.38479263]
