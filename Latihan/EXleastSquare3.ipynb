# %% [markdown]
# NO 3

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [1.5, 2.0, 2.5, 3.0, 3.5]
y = [4.0, 5.1, 6.2, 7.3, 8.4]

x = np.array(x)
y = np.array(y)

A = np.vstack([x, np.ones(len(x))]).T
y = y[:, np.newaxis]

alpha = np.linalg.inv(np.dot(A.T, A)).T
alpha = np.dot(alpha, A.T)
alpha = np.dot(alpha, y)

print(f"Alpha (m and c): {alpha[0]}")
print(alpha[1])

plt.plot(x, y, "ro")
plt.plot(x, alpha[0]*x+alpha[1], 'b')
plt.show()
# Out:
# Alpha (m and c): [2.2]
# [0.7]
